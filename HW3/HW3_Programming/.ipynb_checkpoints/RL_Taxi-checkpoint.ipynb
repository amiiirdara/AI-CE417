# %% [markdown]
# <div align=center>
#
# <font size=5>
# In the Name of God
# <font/>
# <p></p>
# <br/>
# <br/>
# <font>
# Sharif University of Technology - Departmenet of Computer Engineering
# </font>
# <p></p>
# <font color=cyan>
# Artifical Intelligence - Dr. SamiEe
# </font>
# <br/>
# <br/>
#
# <hr/>
# <font color=cyan>
# Reinforcment Learning Practical Assignment
# </font>
# </div>
#
# <ul>
#   <li>Some cell's outputs have not been deleted. you can use these to make sure your implementation is correct.</li>
# </ul>

# %% [markdown]
# In this notebook you will use the [openai gym](https://www.gymlibrary.dev/) library to train agent in reinforcment learning environment. Our environment is a discrete-state env (and it is deterministic).
# make sure to upload your model performance video alongside this notebook. We suggest running this notebook on google colab so that you wont face any package errors.

# %% [markdown]
# we will first install the necessary packages.

# %%
# %pip install gym==0.26
# %pip install imageio imageio_ffmpeg
# %pip install pygame
# %pip install pyglet==1.5.1 
# %apt install python-opengl
# %apt install ffmpeg
# %apt install xvfb
# %pip install pyvirtualdisplay
# %pip install 'gym[box2d]'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym==0.26 in /home/amiiirdara/.local/lib/python3.10/site-packages (0.26.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/lib/python3/dist-packages (from gym==0.26) (1.21.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/amiiirdara/.local/lib/python3.10/site-packages (from gym==0.26) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/amiiirdara/.local/lib/python3.10/site-packages (from gym==0.26) (0.0.8)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imageio in /home/amiiirdara/.local/lib/python3.10/site-packages (2.31.1)
# Requirement already satisfied: imageio_ffmpeg in /home/amiiirdara/.local/lib/python3.10/site-packages (0.4.8)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from imageio) (1.21.5)
# Requirement already satisfied: pillow>=8.3.2 in /usr/lib/python3/dist-packages (from imageio) (9.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pygame in /home/amiiirdara/.local/lib/python3.10/site-packages (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyglet==1.5.1 in /home/amiiirdara/.local/lib/python3.10/site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%apt` not found.

# %% [markdown]
# the functions below will be used to make a video of the model performance. It will start the environment and choose the best action based on the given Qtable.

# %%
from IPython.display import HTML
from base64 import b64encode
import imageio

## comment this part if your not using google colab
# from pyvirtualdisplay import Display
# virtual_display = Display(visible=0, size=(1400, 900))
# virtual_display.start()
######################

def record_video_taxi_env(env, Qtable, out_directory, fps=1, random_action=False):
  images = []  
  done = False
  state, info = env.reset(seed=random.randint(0,500))
  img = env.render()
  images.append(img)
  while not done:
    # Take the action (index) that have the maximum expected future reward given that state
    action = np.random.randint(6)  if random_action else np.argmax(Qtable[state][:])
    state, reward, done, truncated, info = env.step(action)
    img = env.render()
    images.append(img)
  imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)

def show_video(video_path, video_width = 500):
  video_file = open(video_path, "r+b").read()
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
  return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")

# %% [markdown]
# ## Part I: Taxi Environment (35 + 10 Points)

# %%
import numpy as np
import gym
import random
from tqdm import tqdm

# %% [markdown]
# In this exercise, we want to solve the Taxi-v3 environment. It is an environment, where we have a taxi, a passenger and a destination. taxi should go to the passenger's location, pick it up and then reach to destination and drop the passenger.
# Please read more about this environment [here](https://www.gymlibrary.dev/environments/toy_text/taxi/)

# %% [markdown]
# **Question**
# Create an environment with the name `env` and print the number of states and actions.

# %%
env = gym.make('Taxi-v3', render_mode='rgb_array')
states_no = env.observation_space.n
actions_no = env.action_space.n
print('the number of states:', states_no)
print('the number of actions:', actions_no)
# Out:
# the number of states: 500
# the number of actions: 6

# %% [markdown]
# Let's run a random policy in this environement to get a better understanding of it.

# %%
record_video_taxi_env(env, None, 'taxi_random.mp4', fps=10, random_action=True)
show_video('taxi_random.mp4', video_width = 600)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (550, 350) to (560, 352) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# [swscaler @ 0x6f52c00] Warning: data is not aligned! This can lead to a speed loss
# <video width=600 controls><source src="data:video/mp4;base64,..."></video>

# %% [markdown]
# **Question**
#
# Briefly describe the state space, action space, and reward function of this environment.
#
# **Answer:**

# %% [markdown]
# **Question**
#
# Complete the code for `initialize_q_table` function. It should create a Q-table of size (state_space, action_space) and initializes it. You are free to use whichever initialization you want (a good starting point is to initialize it with all zeros)

# %%
def initialize_q_table(state_space_no, action_space_no):
    Qtable = np.zeros((state_space_no, action_space_no))
    return Qtable

# %%
Qtable = initialize_q_table(states_no, actions_no)

# %% [markdown]
# **Question**
#
# Complete the code for `epsilon_greedy_policy` function. It should select the best action according to the current Q-function with probability $1-\varepsilon$ and select a random action with probability $\varepsilon$.

# %%
def epsilon_greedy_policy(Qtable, state, epsilon):
    sample = random.random()
    if sample < epsilon:
        return env.action_space.sample()
    return np.argmax(Qtable[state][:])

# %% [markdown]
# **Question**
# You need to choose appropriate hyperparameters for the agent to learn.
#
# In particular, you must find a suitable learning rate and exploration parameters. To facilitate exploration, a common practice is to start with a high exploration rate ($\varepsilon$) and gradually decrease it as the agent gets better. To implement this, you need to specify the starting exploration rate (`max_epsilon`), the final exploration rate (`min_epsilon`) and a decay rate which reduces the exploration rate after each update (see the `train` function below).

# %%
n_training_episodes = 50_000  
n_eval_episodes = 10_000
learning_rate = 0.55

max_steps = 99     
gamma = 0.95       

max_epsilon = 1
min_epsilon = 0.001
decay_rate = 0.001

# %% [markdown]
# **Question**
#
# Complete the `train` function which updates `Qtable` using the Q-learning update rule.

# %%
import math

def train(n_training_episodes, min_epsilon, max_epsilon, decay_rate, env, max_steps, Qtable):
    episode = 0
    while episode < n_training_episodes:
        epsilon = min_epsilon + (max_epsilon - min_epsilon) * \
            np.exp(-decay_rate * episode)
        state, info = env.reset()
        step = 0
        done = False
        step = 0
        while step < max_steps:
            action = epsilon_greedy_policy(Qtable, state, epsilon)
            next_state, reward, done, truncated, info = env.step(action)
            Qtable[state][action] = Qtable[state][action] + learning_rate * \
                (reward + gamma *
                 np.max(Qtable[next_state][:]) - Qtable[state][action])
            state = next_state
            if done or truncated:
                break
            step += 1
        episode += 1
    return Qtable

# %% [markdown]
# We are now ready to train our agent.

# %%
Qtable_trained = train(n_training_episodes, min_epsilon, max_epsilon, decay_rate, env, max_steps, Qtable)

# %% [markdown]
# Now, we will evaluate our agent. You don't need to write any code, just run the following cells as they are.

# %%
def evaluate_agent(env, max_steps, n_eval_episodes, Q):
  """
  Evaluate the agent for ``n_eval_episodes`` episodes and returns average reward and std of reward.
  :param env: The evaluation environment
  :param n_eval_episodes: Number of episode to evaluate the agent
  :param Q: The Q-table
  """
  episode_rewards = []
  for episode in tqdm(range(n_eval_episodes)):
    state, info = env.reset()
    step = 0
    terminated = False
    total_rewards_ep = 0
    
    for step in range(max_steps):
      action = np.argmax(Q[state][:])
      new_state, reward, terminated, truncated, info = env.step(action)
      total_rewards_ep += reward
        
      if terminated:
        break
      state = new_state
    episode_rewards.append(total_rewards_ep)
  mean_reward = np.mean(episode_rewards)
  std_reward = np.std(episode_rewards)

  return mean_reward, std_reward

# %%
mean_reward, std_reward = evaluate_agent(env, max_steps, n_eval_episodes, Qtable_trained)
print(f"Mean_reward={mean_reward:.2f} +/- {std_reward:.2f}") # should be around 0.65
# Out:
#   0%|                                                                                                             | 0/10000 [00:00<?, ?it/s]
#   5%|█████▏                                                                                           | 537/10000 [00:00<00:01, 5364.88it/s]
#  11%|██████████▎                                                                                     | 1074/10000 [00:00<00:01, 4754.77it/s]
#  16%|███████████████                                                                                 | 1563/10000 [00:00<00:01, 4811.46it/s]
#  20%|███████████████████▋                                                                            | 2047/10000 [00:00<00:01, 4752.00it/s]
#  25%|████████████████████████▏                                                                       | 2524/10000 [00:00<00:01, 4710.33it/s]
#  30%|█████████████████████████████                                                                   | 3029/10000 [00:00<00:01, 4819.51it/s]
#  35%|██████████████████████████████████                                                              | 3544/10000 [00:00<00:01, 4922.80it/s]
#  40%|██████████████████████████████████████▊                                                         | 4038/10000 [00:00<00:01, 4816.05it/s]
#  45%|███████████████████████████████████████████▍                                                    | 4521/10000 [00:00<00:01, 4746.85it/s]
#  50%|████████████████████████████████████████████████▎                                               | 5030/10000 [00:01<00:01, 4849.70it/s]
#  55%|████████████████████████████████████████████████████▉                                           | 5516/10000 [00:01<00:00, 4805.15it/s]
#  60%|█████████████████████████████████████████████████████████▌                                      | 5998/10000 [00:01<00:00, 4744.97it/s]
#  65%|██████████████████████████████████████████████████████████████▏                                 | 6473/10000 [00:01<00:00, 4617.79it/s]
#  69%|██████████████████████████████████████████████████████████████████▌                             | 6936/10000 [00:01<00:00, 4554.39it/s]
#  74%|██████████████████████████████████████████████████████████████████████▉                         | 7394/10000 [00:01<00:00, 4559.90it/s]
#  79%|███████████████████████████████████████████████████████████████████████████▎                    | 7851/10000 [00:01<00:00, 4539.78it/s]
#  83%|███████████████████████████████████████████████████████████████████████████████▋                | 8306/10000 [00:01<00:00, 4453.34it/s]
#  88%|████████████████████████████████████████████████████████████████████████████████████▏           | 8774/10000 [00:01<00:00, 4518.38it/s]
#  92%|████████████████████████████████████████████████████████████████████████████████████████▊       | 9246/10000 [00:01<00:00, 4575.17it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 10000/10000 [00:02<00:00, 4711.22it/s]
# Mean_reward=7.89 +/- 2.60

# %% [markdown]
# Now let's see how well our model is doing.

# %%
record_video_taxi_env(env, Qtable_trained, 'taxi_trained.mp4', fps=10)
show_video('taxi_trained.mp4', video_width = 600)
# Out:
# IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (550, 350) to (560, 352) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video width=400 controls><source src="data:video/mp4;base64,..."></video>

# %% [markdown]
# Next, we will take a look at the Q-function that was learned.

# %%
print(Qtable_trained)
# Out:
# [[ 0.          0.          0.          0.          0.         11.        ]
#  [ 8.69596466 10.20627858  8.69596466 10.20627858 11.79608272  1.20627858]
#  [29.22983086 31.82087459 29.22983086 31.82087459 34.54828905 22.82087459]
#  ...
#  [19.0372483  21.09184031 19.0372483  17.08538588 10.0372483  10.0372483 ]
#  [24.42992235 26.76833932 24.42992235 26.76833932 15.42992235 15.42992235]
#  [43.62243948 40.4413175  43.62243948 46.97098892 34.62243948 34.62243948]]

# %% [markdown]
# **Question**
#
# Assume that `Qtable_trained` is the correct Q-function for the final epsilon-greedy policy that was used in training. What is the value function that corresponds to this policy? Write down the relation between $V_\pi$ and $Q_\pi$ and use it to complete the following code block.

# %% [markdown]
# **Answer:**

# %%
Vtable_trained = np.max(Qtable_trained, axis=1)

# %% [markdown]
# Take a look at the value function

# %%
print(Vtable_trained)
# Out:
#   0%|                                                                                                             | 0/50000 [07:13<?, ?it/s]
#  19.0372483  23.25456875 34.54828905 43.62243948  0.          3.37304256
#  20.09800492 14.37902697  8.69596466  0.         20.09800492 26.76833932
#   8.69596466  3.37304256  0.         14.37902697  8.69596466 11.79608272
#  20.09800492  0.         17.08538588 25.531125   31.82087459 40.4413175
#   0.          7.26116642 26.76833932 20.09800492  2.20439043  0.
#  11.02707184 16.18844944 17.08538588 10.20627858  0.         24.42992235
#   4.6032027   7.26116642 14.37902697  0.         23.25456875 15.23111659
#  46.97098892 31.82087459  0.          5.8981081  24.42992235 18.09310468
#   3.37304256  0.         12.66007562 18.09310468 11.79608272  5.8981081
#   0.         18.09310468  5.8981081   8.69596466 16.18844944  0.
#  21.09184031 17.08538588 37.41925163 34.54828905  0.          4.6032027
#  22.20842624 16.18844944  4.6032027   0.         14.37902697 20.09800492
#  10.20627858  4.6032027   0.         16.18844944  7.26116642 10.20627858
#  18.09310468  0.         19.0372483  19.0372483  34.54828905 37.41925163
#   0.          3.37304256 20.09800492 14.37902697  5.8981081   0.
#  16.18844944 22.20842624  8.69596466  3.37304256  0.         14.37902697
#  11.79608272 15.23111659 24.42992235  0.         17.08538588 21.09184031
#  31.82087459 46.97098892  0.          2.20439043 18.09310468 12.66007562
#   7.26116642  0.         18.09310468 24.42992235  7.26116642  2.20439043
#   0.         12.66007562 10.20627858 13.46956076 22.20842624  0.
#  15.23111659 23.25456875 29.22983086 43.62243948  0.          5.8981081
#  24.42992235 18.09310468  1.09417091  0.          9.47571825 14.37902697
#  19.0372483  11.79608272 32.10081875 26.76833932  3.37304256  5.8981081
#  12.66007562  0.         21.09184031 13.46956076 50.49577781 29.22983086
#   0.          4.6032027  22.20842624 16.18844944  2.20439043  0.
#  11.02707184 16.18844944 10.20627858  4.6032027   0.         16.18844944
#   4.6032027   7.26116642 14.37902697  0.         19.0372483  15.23111659
#  34.54828905 31.82087459  0.          3.37304256 20.09800492 14.37902697
#   3.37304256  0.         12.66007562 18.09310468  8.69596466  3.37304256
#   0.         14.37902697  5.8981081   8.69596466 16.18844944  0.
#  17.08538588 17.08538588 31.82087459 34.54828905  0.          2.20439043
#  18.09310468 12.66007562  4.6032027   0.         14.37902697 20.09800492
#   7.26116642  2.20439043  0.         12.66007562 13.46956076 17.08538588
#  26.76833932 32.10081875 15.23111659 19.0372483  29.22983086 50.49577781
#   0.          1.09417091 16.18844944 11.02707184  5.8981081   0.
#  16.18844944 22.20842624  5.8981081   1.09417091  0.         11.02707184
#  11.79608272 15.23111659 24.42992235  0.         13.46956076 21.09184031
#  26.76833932 46.97098892]

# %% [markdown]
# **Question**
# Write a function to generate a visualization for the value function using a heatmap. In a few words, explain what you see.

# %%
import matplotlib.pyplot as plt


def visualize(Vtable):
    """
    Visualize the value function
    :param Vtable: The value function
    """
    states = range(len(Vtable))
    values = [Vtable[state] for state in states]

    plt.plot(states, values)
    plt.xlabel('State')
    plt.ylabel('Value')
    plt.title('Value Function')
    plt.show()

    
visualize(Vtable_trained)

# %% [markdown]
# **Question**
# Can we use a pure greedy policy for Q-learning? Explain.
